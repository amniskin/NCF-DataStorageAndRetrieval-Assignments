# %% [markdown]
# # Final Exam
# So, after a lot of messing with things, I realized that this needed to be reproducible (something a smarter person than myself would have known from the start). So I switched over to Jupyter Notebooks. I hope this is acceptable.
#
# ## The idea:
#
# ### Suggesting venue improvements:
# I figured we could identify areas where low ranking (via number of stars) could improve upon in order to maximize their star increase. E.g, a coffeshop without wifi might want to get wifi. As it turns out, getting paid wifi is not a good idea for such a coffee shop (go big or go home, I guess).
#
# ### Accounting for venue style:
# It might be that certain types of places (as seen through the 'Ambience' attribute) get rated lower due to the nature of the ambience. For example, if a yelper goes to a dive bar and finds that there are few if any amenities, (s)he might give the bar a low score. Being as how the general user expects dive bars to be amenity lacking, this review is not as informative as others with more aligned expectations.
#
# On the other hand, another yelper might go to an amenity filled "dive bar" and rate it very high due to the amenities. This latter case suggests that ambience should be voted on and set by the yelp community rather than by the establishment itself.
#
# Assuming that the categories are set as described above, we might be able to address the misaligned-expectation-review problem with a weighted average. If we want to get really crazy, which I do, we would add a bit of natural language processing to the mix and for instance, any negative reviews pertaining to dive bars with negative mentions of certain amenities would be weighed less; and any positive reviews with positive mentions of amenities (and not the lack thereof) might also be weighed less.
#
# I suspect this would be a feature requiring some AB testing.
#
# As far as incorporating this feature on more than one category, it could be done by surveys on user expectations. So, for instance, with the dive bar scenario, they could present the users who frequent dive bars in each region with questionaires asking what features they expect from a dive bar, and which they expect a dive bar not to have.
#
# ### Find [bars] within [0.25] miles of [Wi-Fi]:
# Have you ever been working late at night and wished there was a bar or pub you could work from? I know I generally do my best work with a beer. The main deterrent is always the lack of Wi-Fi at these fine establishments.
#
# After part 1, we've noticed that Wi-Fi availability did not really affect the star rating. So we can use our trusty 2dsphere index to find bars that have other locations close by with free Wi-Fi. The idea being that if the Wi-Fi signal is strong/close enough, one might conceivibly be able to use said Wi-Fi while patronizing said bar.
#
# ## Areas for improvement:
#
# 1. Add natural language processing (possibly via nltk available at nltk.org) to classify customer types from the language used in reviews, and suggest amenities that these customers tend to like.
#
# ## Areas where I'm exceedingly stupid:
# 1. Life
# 1. I should have realized that being as how this goal is so vague, I was going to spend most of my time with EDA. So I don't feel as though I've accomplished much outside of eliminating ideas.
# 2. I should have realized that long ago. I don't think I have too much time to work on number 2.

# %% [markdown]
# # Basics:

# %%
import numpy as np
import json
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
from pymongo import MongoClient
from bson import SON

# %%
db = MongoClient().yelp_aaron

# %%
business = db.business

# %%
def getDF(table, predicate, preprocessor=lambda x: x, projection=None):
    tmp = table.find(predicate, projection)
    maxInd = tmp.count()
    print("Found {r} records matching this predicate.".format(r=maxInd))
    retVal = []
    for i in range(maxInd):
        retVal.append(preprocessor(tmp[i]))
    del tmp
    del maxInd
    retVal = pd.DataFrame.from_records(retVal)
    return retVal

# %% [markdown]
# ## How does Wi-Fi affect bars as opposed to coffee-shops?

# %%
def getWifi(rec):
    if 'Wi-Fi' in rec['attributes']:
        rec['wifi'] = rec['attributes']['Wi-Fi']
    else:
        rec['wifi'] = 'Unknown'
    rec.pop('attributes', None)
    return rec

# %% [markdown]
# ### Bars:

# %%
bars = getDF(business,
             {'categories': {'$in': ['Bars']}},
             projection={'attributes.Wi-Fi': 1,
                         'city': 1,
                         'name': 1,
                         'stars': 1},
             preprocessor=getWifi
            )
# Out:
# Found 4727 records matching this predicate.

# %%
bars
# Out:
#                            _id            city  \
# 0     5853170222e2fc4bfd9471ef        Braddock
# 1     5853170222e2fc4bfd9471f1        Carnegie
# 2     5853170222e2fc4bfd9471fd        Carnegie
# 3     5853170222e2fc4bfd947201        Carnegie
# 4     5853170222e2fc4bfd947210       Homestead
# 5     5853170222e2fc4bfd947219       Homestead
# 6     5853170222e2fc4bfd94721a       Homestead
# 7     5853170222e2fc4bfd947224  West Homestead
# 8     5853170222e2fc4bfd947229       Homestead
# 9     5853170222e2fc4bfd94724c    McKees Rocks
# 10    5853170222e2fc4bfd947281      Pittsburgh
# 11    5853170222e2fc4bfd94728e      Pittsburgh
# 12    5853170222e2fc4bfd9472a2      Pittsburgh
# 13    5853170222e2fc4bfd9472ca      Pittsburgh
# 14    5853170222e2fc4bfd9472cc      Pittsburgh
# 15    5853170222e2fc4bfd9472ce      Pittsburgh
# 16    5853170222e2fc4bfd9472d2      Pittsburgh
# 17    5853170222e2fc4bfd9472d4      Pittsburgh
# 18    5853170222e2fc4bfd9472e6      Pittsburgh
# 19    5853170222e2fc4bfd947304      Pittsburgh
# 20    5853170222e2fc4bfd94730b      Pittsburgh
# 21    5853170222e2fc4bfd94730f      Pittsburgh
# 22    5853170222e2fc4bfd94731a      Pittsburgh
# 23    5853170222e2fc4bfd94732c      Pittsburgh
# 24    5853170222e2fc4bfd947336      Pittsburgh
# 25    5853170222e2fc4bfd94733a      Pittsburgh
# 26    5853170222e2fc4bfd94733b      Pittsburgh
# 27    5853170222e2fc4bfd947346      Pittsburgh
# 28    5853170222e2fc4bfd94734e      Pittsburgh
# 29    5853170222e2fc4bfd94736a      Pittsburgh
# ...                        ...             ...
# 4697  5853170a22e2fc4bfd95bfe7         Madison
# 4698  5853170a22e2fc4bfd95bfed      Pittsburgh
# 4699  5853170a22e2fc4bfd95bfef      Scottsdale
# 4700  5853170a22e2fc4bfd95bff1        Montréal
# 4701  5853170a22e2fc4bfd95c00f         Madison
# 4702  5853170a22e2fc4bfd95c011         Phoenix
# 4703  5853170a22e2fc4bfd95c037      Scottsdale
# 4704  5853170a22e2fc4bfd95c03d        Montréal
# 4705  5853170a22e2fc4bfd95c053            Mesa
# 4706  5853170a22e2fc4bfd95c07d       Charlotte
# 4707  5853170a22e2fc4bfd95c07e        Montréal
# 4708  5853170a22e2fc4bfd95c084          Peoria
# 4709  5853170a22e2fc4bfd95c085       Las Vegas
# 4710  5853170a22e2fc4bfd95c08b       Las Vegas
# 4711  5853170a22e2fc4bfd95c09f        Montréal
# 4712  5853170a22e2fc4bfd95c0b2       Charlotte
# 4713  5853170a22e2fc4bfd95c0b3         Phoenix
# 4714  5853170a22e2fc4bfd95c0c2      Pittsburgh
# 4715  5853170a22e2fc4bfd95c0d3        Montréal
# 4716  5853170a22e2fc4bfd95c102       Edinburgh
# 4717  5853170a22e2fc4bfd95c10e         Phoenix
# 4718  5853170a22e2fc4bfd95c111        Montréal
# 4719  5853170a22e2fc4bfd95c115      Pittsburgh
# 4720  5853170a22e2fc4bfd95c119       Las Vegas
# 4721  5853170a22e2fc4bfd95c120         Phoenix
# 4722  5853170a22e2fc4bfd95c141       Las Vegas
# 4723  5853170a22e2fc4bfd95c151          Peoria
# 4724  5853170a22e2fc4bfd95c15d      Scottsdale
# 4725  5853170a22e2fc4bfd95c16e          Laveen
# 4726  5853170a22e2fc4bfd95c16f        Glendale
#
#                                     name  stars     wifi
# 0                          Emil's Lounge    4.5       no
# 1                  Alexion's Bar & Grill    4.0     free
# 2                         Rocky's Lounge    4.0     free
# 3                     Paddy's Pour House    3.5  Unknown
# 4                Randy's Beer Barrel Pub    2.5  Unknown
# 5                 Duke's Upper Deck Cafe    3.5     free
# 6                        Dave & Buster's    2.5     free
# 7                              Bar Louie    2.5     free
# 8                            TGI Fridays    2.5     free
# 9                             Applebee's    3.5  Unknown
# 10                         Buffalo Blues    3.0       no
# 11                         Shadow Lounge    4.5     free
# 12                                Casbah    4.0     free
# 13                        The Park House    4.0  Unknown
# 14                Max's Allegheny Tavern    4.0       no
# 15                           Mt Troy Inn    3.5  Unknown
# 16                              Key West    3.5  Unknown
# 17                     Clark Bar & Grill    3.5       no
# 18                               Peanutz    2.5  Unknown
# 19                             Apple Inn    3.0  Unknown
# 20                                Huddle    4.0       no
# 21                                 Vasta    2.5  Unknown
# 22                             Slapshots    2.0  Unknown
# 23      Bado's Pizza Grill and Ale House    3.5     free
# 24                    D's Six Pax & Dogz    4.5     free
# 25                       Pub In the Park    4.5  Unknown
# 26                     Murphy's Tap Room    3.0  Unknown
# 27                  Triangle Bar & Grill    4.5       no
# 28                            Applebee's    2.5       no
# 29                    Tramp's Restaurant    3.5     free
# ...                                  ...    ...      ...
# 4697         608 Sports Bar & Restaurant    3.0  Unknown
# 4698        Caliente Pizza & Draft House    3.0  Unknown
# 4699        Bones Rock & Roll Strip Club    2.5  Unknown
# 4700          Café Bar St-Laurent Frappé    2.5  Unknown
# 4701                             Lucille    3.5       no
# 4702                             Wink 24    5.0  Unknown
# 4703                               I-MAD    5.0  Unknown
# 4704                         Pit Caribou    4.5  Unknown
# 4705                 BullPen Bar n Grill    3.0     free
# 4706                          Moo & Brew    4.0     free
# 4707                            Pompette    5.0     free
# 4708                        Modern Round    3.5     free
# 4709                          PT's Ranch    3.5     free
# 4710           The Mixx Grill and Lounge    4.5     free
# 4711                        Le Warehouse    3.5  Unknown
# 4712                         City Lights    3.0       no
# 4713  The Living Room Wine Café & Lounge    3.5     free
# 4714                     Local Brewhouse    3.5  Unknown
# 4715                     Tacos El Gordos    2.0  Unknown
# 4716                        Badger & Co.    5.0  Unknown
# 4717               Honor Amongst Thieves    3.5       no
# 4718                            L'Escale    3.0  Unknown
# 4719            East End Brewing Taproom    4.5  Unknown
# 4720                  Bubby's University    3.5  Unknown
# 4721                     Torch Cigar Bar    5.0  Unknown
# 4722                             PUB 365    4.0     free
# 4723     El Alboroto Mariscos & Chavelas    4.0  Unknown
# 4724             CM2 Pizzeria & Bakeshop    5.0  Unknown
# 4725             Greathouse Sports Grill    2.0  Unknown
# 4726                           Bar Louie    2.5  Unknown
#
# [4727 rows x 5 columns]

# %%
bars.groupby(by='wifi').mean()
# Out:
#             stars
# wifi
# Unknown  3.550434
# free     3.541452
# no       3.490450
# paid     3.473684

# %%
bars_lm = ols('stars ~ C(wifi)', data=bars).fit()

# %%
print(sm.stats.anova_lm(bars_lm, typ=2))
# Out:
#                sum_sq      df         F    PR(>F)
# C(wifi)      2.128350     3.0  1.633234  0.179445
# Residual  2051.593355  4723.0       NaN       NaN

# %% [markdown]
# So we see that the wifi availability is inconsequential with respect to the mean star rating.
# ### General food service industry:

# %%
food = getDF(business,
              {'categories': {'$in': ['Food']}},
              projection={'attributes.Wi-Fi': 1,
                          'city': 1,
                          'name': 1,
                          'stars': 1},
              preprocessor=getWifi
             )
# Out:
# Found 10143 records matching this predicate.

# %%
food_lm = ols('stars ~ C(wifi)', data=food).fit()
print(sm.stats.anova_lm(food_lm, typ=2))
# Out:
#                sum_sq       df         F    PR(>F)
# C(wifi)      8.706789      3.0  4.562756  0.003375
# Residual  6449.181902  10139.0       NaN       NaN

# %%
food.groupby(by='wifi').mean()
# Out:
#             stars
# wifi
# Unknown  3.725182
# free     3.765854
# no       3.799819
# paid     3.642857

# %% [markdown]
# Again, we find very little influence if any.
#
# ### Coffee-Shops:

# %%
coffee = getDF(business,
               {'categories': {'$in': ['Coffee & Tea']}},
               projection={'attributes.Wi-Fi': 1,
                           'city': 1,
                           'name': 1,
                           'stars': 1},
               preprocessor=getWifi
              )
# Out:
# Found 2399 records matching this predicate.

# %%
coffee.groupby(by='wifi').mean()
# Out:
#             stars
# wifi
# Unknown  3.764012
# free     3.709521
# no       3.829114
# paid     3.250000

# %%
coffee_lm = ols('stars ~ C(wifi)', data=coffee).fit()
print(sm.stats.anova_lm(coffee_lm, typ=2))
# Out:
#                sum_sq      df         F    PR(>F)
# C(wifi)      8.614933     3.0  5.058178  0.001709
# Residual  1359.696655  2395.0       NaN       NaN

# %%
coffee_lm.pvalues
# Out:
# Intercept          0.000000
# C(wifi)[T.free]    0.225360
# C(wifi)[T.no]      0.243320
# C(wifi)[T.paid]    0.007715
# dtype: float64

# %% [markdown]
# So we can see that it's pretty bad to charge for wifi at your coffeeshop (the low p-value associated to 'paid' wifi suggests that this is not just spurious).

# %% [markdown]
# ## Low ranking suggestions:
# ### Warning: This was a failure, but there are interesting threads I want to explore later, so I'm not deleting them. It might be best to move on to the next section.

# %%
lowRankCoffee = coffee[coffee['stars'] < 3]

# %%
def getAllAttrs(rec):
    rec = dict(rec, **rec['attributes'])
    rec.pop('attributes', None)
    return rec
def getAmbience(rec):
    if 'Ambience' in rec['attributes']:
        rec = dict(rec, **rec['attributes']['Ambience'])
        rec.pop('attributes', None) 
        return rec

# %%
coffee_full = getDF(business,
                    {'categories': {'$in': ['Coffee & Tea']}},
                    projection={'attributes': 1,
                                'city': 1,
                                'stars': 1},
                    preprocessor=getAllAttrs
                   )
# Out:
# Found 2399 records matching this predicate.

# %%
coffee_full
# Out:
#      Accepts Credit Cards Accepts Insurance Ages Allowed Alcohol  \
# 0                    True               NaN          NaN    none
# 1                    True               NaN          NaN    none
# 2                    True               NaN          NaN    none
# 3                    True               NaN          NaN     NaN
# 4                   False               NaN          NaN     NaN
# 5                    True               NaN          NaN     NaN
# 6                    True               NaN          NaN     NaN
# 7                    True               NaN          NaN     NaN
# 8                    True               NaN          NaN     NaN
# 9                   False               NaN          NaN     NaN
# 10                    NaN               NaN          NaN     NaN
# 11                   True               NaN          NaN     NaN
# 12                   True               NaN          NaN    none
# 13                   True               NaN          NaN     NaN
# 14                   True               NaN          NaN     NaN
# 15                   True               NaN          NaN     NaN
# 16                   True               NaN          NaN     NaN
# 17                   True               NaN          NaN     NaN
# 18                   True               NaN          NaN     NaN
# 19                   True               NaN          NaN     NaN
# 20                   True               NaN          NaN     NaN
# 21                   True               NaN          NaN     NaN
# 22                   True               NaN          NaN     NaN
# 23                   True               NaN          NaN     NaN
# 24                   True               NaN          NaN    none
# 25                   True               NaN          NaN     NaN
# 26                   True               NaN          NaN     NaN
# 27                   True               NaN          NaN    none
# 28                   True               NaN          NaN     NaN
# 29                   True               NaN          NaN     NaN
# ...                   ...               ...          ...     ...
# 2369                 True               NaN          NaN    none
# 2370                 True               NaN          NaN     NaN
# 2371                  NaN               NaN          NaN     NaN
# 2372                 True               NaN          NaN     NaN
# 2373                 True               NaN          NaN     NaN
# 2374                 True               NaN          NaN     NaN
# 2375                 True               NaN          NaN    none
# 2376                 True               NaN          NaN    none
# 2377                  NaN               NaN          NaN    none
# 2378                  NaN               NaN          NaN    none
# 2379                False               NaN          NaN    none
# 2380                 True               NaN          NaN     NaN
# 2381                 True               NaN          NaN    none
# 2382                 True               NaN          NaN     NaN
# 2383                 True               NaN          NaN     NaN
# 2384                 True               NaN          NaN     NaN
# 2385                 True               NaN          NaN     NaN
# 2386                  NaN               NaN          NaN     NaN
# 2387                 True               NaN          NaN     NaN
# 2388                 True               NaN          NaN     NaN
# 2389                 True               NaN          NaN     NaN
# 2390                 True               NaN          NaN     NaN
# 2391                 True               NaN          NaN    none
# 2392                 True               NaN          NaN    none
# 2393                 True               NaN          NaN     NaN
# 2394                 True               NaN          NaN     NaN
# 2395                  NaN               NaN          NaN    none
# 2396                 True               NaN          NaN     NaN
# 2397                  NaN               NaN          NaN     NaN
# 2398                 True               NaN          NaN    none
#
#                                                Ambience  Attire BYOB  \
# 0                                                   NaN     NaN  NaN
# 1     {'divey': False, 'romantic': False, 'hipster':...  casual  NaN
# 2     {'divey': False, 'romantic': False, 'hipster':...  casual  NaN
# 3                                                   NaN     NaN  NaN
# 4                                                   NaN     NaN  NaN
# 5                                                   NaN     NaN  NaN
# 6                                                   NaN     NaN  NaN
# 7                                                   NaN     NaN  NaN
# 8                                                   NaN     NaN  NaN
# 9                                                   NaN     NaN  NaN
# 10                                                  NaN     NaN  NaN
# 11                                                  NaN     NaN  NaN
# 12    {'divey': False, 'romantic': False, 'hipster':...  casual  NaN
# 13                                                  NaN     NaN  NaN
# 14                                                  NaN     NaN  NaN
# 15                                                  NaN     NaN  NaN
# 16                                                  NaN     NaN  NaN
# 17                                                  NaN     NaN  NaN
# 18                                                  NaN     NaN  NaN
# 19                                                  NaN     NaN  NaN
# 20                                                  NaN     NaN  NaN
# 21                                                  NaN     NaN  NaN
# 22                                                  NaN     NaN  NaN
# 23                                                  NaN     NaN  NaN
# 24    {'divey': True, 'romantic': False, 'hipster': ...  casual  NaN
# 25                                                  NaN     NaN  NaN
# 26                                                  NaN     NaN  NaN
# 27                                                  NaN     NaN  NaN
# 28                                                  NaN     NaN  NaN
# 29                                                  NaN     NaN  NaN
# ...                                                 ...     ...  ...
# 2369  {'divey': True, 'romantic': False, 'hipster': ...  casual  NaN
# 2370                                                NaN  casual  NaN
# 2371  {'divey': False, 'romantic': False, 'hipster':...     NaN  NaN
# 2372                                                NaN     NaN  NaN
# 2373                                                NaN     NaN  NaN
# 2374                                                NaN     NaN  NaN
# 2375  {'divey': False, 'romantic': False, 'hipster':...  casual  NaN
# 2376                                                NaN     NaN  NaN
# 2377                                                NaN     NaN  NaN
# 2378                                                NaN     NaN  NaN
# 2379                                                NaN     NaN  NaN
# 2380                                                NaN     NaN  NaN
# 2381                                                NaN     NaN  NaN
# 2382                                                NaN     NaN  NaN
# 2383                                                NaN     NaN  NaN
# 2384                                                NaN     NaN  NaN
# 2385                                                NaN     NaN  NaN
# 2386                                                NaN     NaN  NaN
# 2387                                                NaN     NaN  NaN
# 2388                                                NaN     NaN  NaN
# 2389                                                NaN     NaN  NaN
# 2390                                                NaN     NaN  NaN
# 2391                                                NaN     NaN  NaN
# 2392                                                NaN  casual  NaN
# 2393                                                NaN     NaN  NaN
# 2394                                                NaN     NaN  NaN
# 2395  {'divey': False, 'romantic': False, 'hipster':...     NaN  NaN
# 2396                                                NaN     NaN  NaN
# 2397  {'divey': False, 'romantic': False, 'hipster':...  casual  NaN
# 2398                                                NaN     NaN  NaN
#
#      BYOB/Corkage By Appointment Only Caters  ...  Smoking Take-out  \
# 0             NaN               False    NaN  ...      NaN     True
# 1             NaN                 NaN  False  ...      NaN     True
# 2     yes_corkage                 NaN   True  ...      NaN     True
# 3             NaN                 NaN    NaN  ...      NaN      NaN
# 4             NaN                 NaN    NaN  ...      NaN      NaN
# 5             NaN                 NaN    NaN  ...      NaN     True
# 6             NaN                 NaN    NaN  ...      NaN     True
# 7             NaN                 NaN    NaN  ...      NaN     True
# 8             NaN                 NaN    NaN  ...      NaN     True
# 9             NaN                 NaN    NaN  ...      NaN      NaN
# 10            NaN                 NaN    NaN  ...      NaN      NaN
# 11            NaN                 NaN    NaN  ...      NaN      NaN
# 12            NaN                 NaN   True  ...      NaN     True
# 13            NaN                 NaN    NaN  ...      NaN      NaN
# 14            NaN                 NaN    NaN  ...      NaN     True
# 15            NaN                 NaN    NaN  ...      NaN     True
# 16            NaN               False    NaN  ...      NaN     True
# 17            NaN                 NaN    NaN  ...      NaN     True
# 18            NaN                 NaN    NaN  ...      NaN      NaN
# 19            NaN                 NaN    NaN  ...      NaN     True
# 20            NaN                 NaN    NaN  ...      NaN      NaN
# 21            NaN                 NaN    NaN  ...      NaN     True
# 22            NaN                 NaN    NaN  ...      NaN      NaN
# 23            NaN                 NaN    NaN  ...      NaN     True
# 24            NaN                 NaN   True  ...      NaN     True
# 25            NaN                 NaN    NaN  ...      NaN      NaN
# 26            NaN                 NaN    NaN  ...      NaN      NaN
# 27            NaN                 NaN  False  ...      NaN     True
# 28            NaN                 NaN    NaN  ...      NaN      NaN
# 29            NaN                 NaN    NaN  ...      NaN     True
# ...           ...                 ...    ...  ...      ...      ...
# 2369          NaN                 NaN   True  ...      NaN     True
# 2370          NaN                 NaN    NaN  ...      NaN     True
# 2371          NaN                 NaN    NaN  ...      NaN     True
# 2372          NaN                 NaN    NaN  ...      NaN     True
# 2373          NaN                 NaN    NaN  ...      NaN      NaN
# 2374          NaN               False    NaN  ...      NaN     True
# 2375          NaN                 NaN   True  ...      NaN     True
# 2376          NaN               False    NaN  ...      NaN     True
# 2377          NaN                 NaN    NaN  ...      NaN     True
# 2378          NaN                 NaN   True  ...      NaN     True
# 2379          NaN                 NaN    NaN  ...      NaN     True
# 2380          NaN                 NaN    NaN  ...      NaN     True
# 2381          NaN                 NaN  False  ...      NaN     True
# 2382          NaN                 NaN    NaN  ...      NaN     True
# 2383          NaN                 NaN    NaN  ...      NaN      NaN
# 2384          NaN               False    NaN  ...      NaN     True
# 2385          NaN                 NaN   True  ...      NaN      NaN
# 2386          NaN                 NaN    NaN  ...      NaN     True
# 2387          NaN                 NaN    NaN  ...      NaN      NaN
# 2388          NaN                 NaN    NaN  ...      NaN     True
# 2389          NaN                 NaN    NaN  ...      NaN     True
# 2390          NaN                 NaN    NaN  ...      NaN     True
# 2391          NaN                 NaN   True  ...      NaN     True
# 2392          NaN                 NaN    NaN  ...      NaN     True
# 2393          NaN                 NaN    NaN  ...      NaN    False
# 2394          NaN                 NaN    NaN  ...      NaN      NaN
# 2395          NaN                 NaN   True  ...      NaN     True
# 2396          NaN                 NaN    NaN  ...      NaN     True
# 2397          NaN                 NaN    NaN  ...      NaN      NaN
# 2398          NaN                 NaN   True  ...      NaN     True
#
#      Takes Reservations Waiter Service Wheelchair Accessible Wi-Fi  \
# 0                   NaN            NaN                  True  free
# 1                 False          False                  True  free
# 2                 False           True                  True  free
# 3                   NaN            NaN                   NaN    no
# 4                   NaN            NaN                  True  free
# 5                   NaN            NaN                  True  free
# 6                   NaN            NaN                   NaN  free
# 7                   NaN            NaN                  True    no
# 8                   NaN            NaN                  True    no
# 9                   NaN            NaN                   NaN    no
# 10                  NaN            NaN                   NaN   NaN
# 11                  NaN            NaN                  True   NaN
# 12                False          False                  True    no
# 13                  NaN            NaN                   NaN  free
# 14                  NaN            NaN                   NaN  free
# 15                  NaN            NaN                  True  free
# 16                  NaN            NaN                  True  free
# 17                  NaN            NaN                   NaN  free
# 18                  NaN            NaN                   NaN  free
# 19                  NaN            NaN                  True  free
# 20                  NaN            NaN                  True  free
# 21                  NaN            NaN                   NaN   NaN
# 22                  NaN            NaN                  True  free
# 23                  NaN            NaN                   NaN  free
# 24                False          False                 False    no
# 25                  NaN            NaN                  True  free
# 26                  NaN            NaN                   NaN  free
# 27                  NaN            NaN                  True  free
# 28                  NaN            NaN                  True  free
# 29                  NaN            NaN                   NaN  free
# ...                 ...            ...                   ...   ...
# 2369              False          False                  True    no
# 2370              False            NaN                   NaN   NaN
# 2371              False            NaN                   NaN  free
# 2372                NaN            NaN                  True  free
# 2373                NaN            NaN                  True   NaN
# 2374                NaN            NaN                  True  free
# 2375              False          False                  True  free
# 2376                NaN            NaN                  True  free
# 2377              False          False                   NaN    no
# 2378                NaN            NaN                   NaN    no
# 2379                NaN            NaN                  True   NaN
# 2380                NaN            NaN                  True    no
# 2381                NaN            NaN                   NaN  free
# 2382                NaN            NaN                  True  free
# 2383                NaN            NaN                   NaN  free
# 2384                NaN            NaN                   NaN  free
# 2385                NaN            NaN                  True    no
# 2386                NaN            NaN                   NaN  free
# 2387                NaN            NaN                   NaN  free
# 2388                NaN            NaN                   NaN  free
# 2389                NaN            NaN                  True  free
# 2390                NaN            NaN                  True    no
# 2391                NaN            NaN                  True    no
# 2392              False          False                   NaN   NaN
# 2393                NaN            NaN                   NaN  free
# 2394                NaN            NaN                   NaN  free
# 2395                NaN          False                   NaN   NaN
# 2396                NaN            NaN                  True  free
# 2397               True          False                   NaN   NaN
# 2398                NaN            NaN                  True    no
#
#                            _id        city  \
# 0     5848a79739a36819a9b309e4   Homestead
# 1     5848a79739a36819a9b30a55  Pittsburgh
# 2     5848a79739a36819a9b30a79  Pittsburgh
# 3     5848a79739a36819a9b30abc  Pittsburgh
# 4     5848a79739a36819a9b30b16  Pittsburgh
# 5     5848a79739a36819a9b30b37  Pittsburgh
# 6     5848a79739a36819a9b30b4b  Pittsburgh
# 7     5848a79739a36819a9b30b64  Pittsburgh
# 8     5848a79739a36819a9b30b79  Pittsburgh
# 9     5848a79739a36819a9b30b7d  Pittsburgh
# 10    5848a79739a36819a9b30b85  Pittsburgh
# 11    5848a79739a36819a9b30bb5  Pittsburgh
# 12    5848a79739a36819a9b30bc4  Pittsburgh
# 13    5848a79739a36819a9b30bcf  Pittsburgh
# 14    5848a79739a36819a9b30bd5  Pittsburgh
# 15    5848a79739a36819a9b30c3e  Pittsburgh
# 16    5848a79739a36819a9b30c58  Pittsburgh
# 17    5848a79739a36819a9b30d1e   Pineville
# 18    5848a79739a36819a9b30d68   Charlotte
# 19    5848a79739a36819a9b30d73   Charlotte
# 20    5848a79739a36819a9b30d90   Charlotte
# 21    5848a79739a36819a9b30d9d   Charlotte
# 22    5848a79739a36819a9b30dc5   Charlotte
# 23    5848a79739a36819a9b30dc9   Charlotte
# 24    5848a79739a36819a9b30dd4   Charlotte
# 25    5848a79739a36819a9b30df7   Charlotte
# 26    5848a79839a36819a9b30f4e   Charlotte
# 27    5848a79839a36819a9b30f57   Charlotte
# 28    5848a79839a36819a9b30f93   Charlotte
# 29    5848a79839a36819a9b30fb3   Charlotte
# ...                        ...         ...
# 2369  5848a7a239a36819a9b4551c   Las Vegas
# 2370  5848a7a339a36819a9b456fd     Phoenix
# 2371  5848a7a339a36819a9b458d2    Montréal
# 2372  5848a79839a36819a9b31154     Madison
# 2373  5848a79839a36819a9b31768     Phoenix
# 2374  5848a79939a36819a9b34a37       Tempe
# 2375  5848a79b39a36819a9b374de  Scottsdale
# 2376  5848a79b39a36819a9b37bf3        Mesa
# 2377  5848a79b39a36819a9b38154    Montréal
# 2378  5848a79b39a36819a9b381a5    Montréal
# 2379  5848a79c39a36819a9b39123   Edinburgh
# 2380  5848a79c39a36819a9b39d62   Las Vegas
# 2381  5848a79d39a36819a9b3ab80        Mesa
# 2382  5848a79d39a36819a9b3bc5b   Las Vegas
# 2383  5848a79e39a36819a9b3c2a2     Phoenix
# 2384  5848a79f39a36819a9b3ed75   Henderson
# 2385  5848a7a039a36819a9b40300   Las Vegas
# 2386  5848a7a039a36819a9b40f05    Montréal
# 2387  5848a7a039a36819a9b41654     Phoenix
# 2388  5848a7a139a36819a9b41c0f   Edinburgh
# 2389  5848a7a139a36819a9b42aaa  Scottsdale
# 2390  5848a7a139a36819a9b42db9  Pittsburgh
# 2391  5848a7a239a36819a9b43b8b       Tempe
# 2392  5848a7a239a36819a9b43c1c     Phoenix
# 2393  5848a7a239a36819a9b44016     Phoenix
# 2394  5848a7a239a36819a9b44ab0      Urbana
# 2395  5848a7a239a36819a9b44c44   Henderson
# 2396  5848a7a239a36819a9b4510d   Las Vegas
# 2397  5848a7a339a36819a9b455c6    Montréal
# 2398  5848a7a339a36819a9b4587c     Phoenix
#
#                                      name stars
# 0                               Starbucks   3.5
# 1         Tazza D'oro Cafe & Espresso Bar   4.5
# 2     Quiet Storm Vegetarian & Vegan Cafe   4.0
# 3                       Cool Beans Coffee   5.0
# 4                               Katerbean   1.5
# 5                               Starbucks   4.5
# 6                               Starbucks   3.5
# 7                         Nicholas Coffee   4.0
# 8                    La Prima Espresso Co   4.5
# 9                    Fifth Avenue Beanery   3.5
# 10                      Cool Beans Coffee   3.0
# 11               Fortunes Coffee Roastery   4.0
# 12              Prestogeorge Coffee & Tea   4.5
# 13                              Starbucks   4.0
# 14                              Starbucks   3.5
# 15                          Uptown Coffee   4.0
# 16                           Jitters Cafe   4.0
# 17                              Starbucks   3.5
# 18                         Jackson's Java   3.5
# 19                              Starbucks   3.0
# 20               Charlotte Coffee Station   4.5
# 21                              Java Joes   5.0
# 22                         Caribou Coffee   3.5
# 23                         Caribou Coffee   4.5
# 24               Tic Toc Diner & Catering   4.5
# 25                            CoffeeWorks   3.5
# 26        Coffee House At Mountain Island   4.5
# 27                         Caribou Coffee   4.5
# 28                              Starbucks   3.0
# 29                              Starbucks   3.5
# ...                                   ...   ...
# 2369                            Donut Bar   4.5
# 2370                P.A.K Crepes & Coffee   5.0
# 2371                              Esquina   5.0
# 2372                            Cafe Zoma   3.5
# 2373                    Coffee Plantation   1.5
# 2374                            Starbucks   3.5
# 2375                 Einstein Bros Bagels   3.0
# 2376               Krispy Kreme Doughnuts   3.5
# 2377                 Au Festin de Babette   4.0
# 2378                       La Cornetteria   4.0
# 2379                        Picnic Basket   4.5
# 2380         Greenwich Village Coffee Co.   4.0
# 2381                            Starbucks   4.0
# 2382                            Starbucks   3.0
# 2383                            Starbucks   3.5
# 2384                            Starbucks   2.5
# 2385       Bad Ass Coffee of Hawaii Truck   5.0
# 2386                   L'Armoire à Glaces   4.5
# 2387                            Starbucks   4.0
# 2388                     Machina Espresso   5.0
# 2389                      Cream City Cafe   4.0
# 2390                 Pink Box Bakery Cafe   4.0
# 2391                       Affogato Truck   5.0
# 2392                              Café 51   4.0
# 2393                 First Draft Book Bar   4.5
# 2394                            Starbucks   3.0
# 2395                        Scorpion Cafe   5.0
# 2396                   Chewy Boba Company   4.5
# 2397                            Le Coin B   4.0
# 2398                       Pour Jo Coffee   5.0
#
# [2399 rows x 39 columns]

# %%
coffeeAmbience = getDF(business,
                       {'categories': {'$in': ['Coffee & Tea']}, 'attributes.Ambience': {'$exists': True}},
                       projection={'attributes.Ambience': 1,
                                   'city': 1,
                                   'stars': 1},
                       preprocessor=getAmbience
                      )
# Out:
# Found 554 records matching this predicate.

# %%
coffeeAmbience
# Out:
#                           _id casual             city classy  divey hipster  \
# 0    5848a79739a36819a9b30a55   True       Pittsburgh  False  False   False
# 1    5848a79739a36819a9b30a79  False       Pittsburgh  False  False    True
# 2    5848a79739a36819a9b30bc4  False       Pittsburgh  False  False   False
# 3    5848a79739a36819a9b30dd4  False        Charlotte  False   True   False
# 4    5848a79839a36819a9b3106d   True        Middleton  False  False   False
# 5    5848a79839a36819a9b31141   True          Madison  False  False   False
# 6    5848a79839a36819a9b31441  False          Phoenix  False  False   False
# 7    5848a79839a36819a9b31448   True          Phoenix  False  False   False
# 8    5848a79839a36819a9b3173b  False          Phoenix  False  False   False
# 9    5848a79839a36819a9b3176a  False          Phoenix  False   True   False
# 10   5848a79839a36819a9b321a6   True          Gilbert  False  False   False
# 11   5848a79839a36819a9b32301   True       Scottsdale  False  False   False
# 12   5848a79839a36819a9b32a8d   True       Wickenburg  False  False   False
# 13   5848a79939a36819a9b32dd7   True        Las Vegas  False  False   False
# 14   5848a79939a36819a9b32eae   True        Las Vegas  False  False   False
# 15   5848a79939a36819a9b334bc  False       Pittsburgh  False   True   False
# 16   5848a79939a36819a9b33566  False       Pittsburgh  False  False   False
# 17   5848a79939a36819a9b335d0  False       Pittsburgh  False  False   False
# 18   5848a79939a36819a9b335e2   True       Pittsburgh  False  False   False
# 19   5848a79939a36819a9b33808  False        Charlotte  False  False   False
# 20   5848a79939a36819a9b33861  False        Charlotte  False   True   False
# 21   5848a79939a36819a9b33bb8   True          Madison  False  False   False
# 22   5848a79939a36819a9b33bf6   True          Madison  False  False   False
# 23   5848a79939a36819a9b33c00   True          Madison  False  False   False
# 24   5848a79939a36819a9b33c0f  False          Madison  False  False   False
# 25   5848a79939a36819a9b33c14  False          Madison  False  False    True
# 26   5848a79939a36819a9b33d91   True        Fitchburg  False  False   False
# 27   5848a79939a36819a9b33e21   True           Urbana  False  False   False
# 28   5848a79939a36819a9b3435b  False         Chandler  False  False   False
# 29   5848a79939a36819a9b3493a   True            Tempe  False  False   False
# ..                        ...    ...              ...    ...    ...     ...
# 524  5848a7a239a36819a9b45342  False       Scottsdale  False  False   False
# 525  5848a7a239a36819a9b4536f  False          Madison  False  False    True
# 526  5848a7a239a36819a9b45467  False             Mesa  False  False   False
# 527  5848a7a239a36819a9b45494  False        Las Vegas  False  False   False
# 528  5848a7a239a36819a9b45528  False          Phoenix  False  False   False
# 529  5848a7a239a36819a9b4554f   True       Pittsburgh  False  False   False
# 530  5848a7a239a36819a9b45553  False          Phoenix  False  False    True
# 531  5848a7a239a36819a9b4559e  False          Gilbert  False  False   False
# 532  5848a7a339a36819a9b455a8   True  North Las Vegas  False  False   False
# 533  5848a7a339a36819a9b455fb   True          Phoenix  False  False   False
# 534  5848a7a339a36819a9b4562a  False        Edinburgh  False  False   False
# 535  5848a7a339a36819a9b45646  False          Madison  False  False   False
# 536  5848a7a339a36819a9b456ff  False          Madison  False  False   False
# 537  5848a7a339a36819a9b45733   True        Henderson  False  False   False
# 538  5848a7a339a36819a9b4577e  False        Las Vegas  False   True   False
# 539  5848a7a339a36819a9b457d5   True          Phoenix  False  False   False
# 540  5848a7a339a36819a9b4588b  False        Las Vegas  False  False   False
# 541  5848a7a339a36819a9b45903  False          Gilbert  False  False   False
# 542  5848a79b39a36819a9b37088  False        Las Vegas  False  False   False
# 543  5848a79b39a36819a9b3759f  False       Pittsburgh  False  False   False
# 544  5848a79b39a36819a9b37768  False          Phoenix  False  False    True
# 545  5848a79b39a36819a9b37f46  False         Montréal  False  False   False
# 546  5848a79c39a36819a9b38eb3  False        Edinburgh  False    NaN   False
# 547  5848a79c39a36819a9b399a2  False       Scottsdale  False  False   False
# 548  5848a7a039a36819a9b40900  False       Pittsburgh  False  False   False
# 549  5848a7a239a36819a9b4551c  False        Las Vegas  False   True   False
# 550  5848a7a339a36819a9b458d2  False         Montréal  False  False   False
# 551  5848a79b39a36819a9b374de   True       Scottsdale  False  False   False
# 552  5848a7a239a36819a9b44c44  False        Henderson  False  False   False
# 553  5848a7a339a36819a9b455c6  False         Montréal  False  False   False
#
#     intimate romantic  stars touristy trendy upscale
# 0      False    False    4.5    False  False   False
# 1      False    False    4.0    False  False   False
# 2      False    False    4.5    False  False   False
# 3      False    False    4.5    False  False   False
# 4      False    False    3.5    False  False   False
# 5      False    False    4.5    False  False   False
# 6      False    False    4.0    False  False   False
# 7      False    False    4.0    False  False   False
# 8      False    False    4.0    False  False   False
# 9      False    False    4.0    False  False   False
# 10     False    False    4.0    False  False   False
# 11     False    False    3.5    False  False   False
# 12     False    False    4.0    False  False   False
# 13     False    False    4.5    False  False   False
# 14     False    False    3.0    False  False   False
# 15     False    False    4.0    False  False   False
# 16     False    False    3.5    False  False   False
# 17     False    False    3.5    False  False   False
# 18     False    False    4.5    False  False   False
# 19     False    False    4.5    False   True   False
# 20     False    False    4.5    False  False   False
# 21     False    False    4.0    False  False   False
# 22     False    False    3.5    False  False   False
# 23     False    False    3.5    False  False   False
# 24     False    False    4.0    False  False   False
# 25     False    False    4.0    False  False   False
# 26     False    False    4.0    False  False   False
# 27     False    False    3.5    False  False   False
# 28     False    False    4.0    False  False     NaN
# 29     False    False    3.0    False  False   False
# ..       ...      ...    ...      ...    ...     ...
# 524    False    False    4.5    False   True   False
# 525    False    False    4.0    False  False   False
# 526    False    False    5.0    False  False   False
# 527    False    False    4.5    False  False   False
# 528    False    False    5.0    False  False   False
# 529    False    False    4.0    False  False   False
# 530    False    False    4.5    False  False   False
# 531    False    False    3.0    False  False   False
# 532    False    False    4.5    False  False   False
# 533    False    False    5.0    False  False   False
# 534    False    False    4.0    False  False   False
# 535    False    False    4.0    False  False   False
# 536    False    False    5.0    False  False   False
# 537    False    False    3.0    False  False   False
# 538    False    False    4.5    False  False   False
# 539    False    False    4.5    False  False   False
# 540    False    False    4.0    False  False   False
# 541    False    False    4.0    False  False   False
# 542    False    False    4.0    False  False   False
# 543    False    False    4.5    False  False   False
# 544    False    False    4.0    False  False   False
# 545    False    False    3.0    False  False   False
# 546    False    False    4.5    False  False   False
# 547    False    False    4.0    False  False   False
# 548    False    False    3.5    False  False   False
# 549    False    False    4.5    False  False   False
# 550    False    False    5.0    False  False   False
# 551    False    False    3.0    False  False   False
# 552    False    False    5.0    False  False   False
# 553    False    False    4.0    False  False   False
#
# [554 rows x 12 columns]

# %%
coffee_amb_lm = ols('stars ~ C(city)', data=coffeeAmbience).fit()
print(sm.stats.anova_lm(coffee_amb_lm, typ=2))
# Out:
#               sum_sq     df        F    PR(>F)
# C(city)    25.047838   51.0  1.45532  0.025384
# Residual  169.412451  502.0      NaN       NaN

# %%
coffeeAmbience.groupby(by="city").mean()
# Out:
#                    casual    classy  intimate  romantic     stars  touristy  \
# city
# Ahwatukee        1.000000  0.000000  0.000000  0.000000  4.000000  0.000000
# Avondale         0.000000  0.000000  0.000000  0.000000  4.500000  0.000000
# Bellevue         0.000000  0.000000  0.000000  0.000000  4.500000  0.000000
# Brossard         0.000000  0.000000  0.000000  0.000000  4.500000  0.000000
# Buckeye          0.500000  0.000000  0.000000  0.000000  4.000000  0.000000
# Carefree         1.000000  0.000000  0.000000  0.000000  4.000000  0.000000
# Carnegie         1.000000  0.000000  0.000000  0.000000  4.000000  0.000000
# Casa Grande      0.000000  0.000000  0.000000  0.000000  4.500000  0.000000
# Cave Creek       0.800000  0.000000  0.000000  0.000000  4.400000  0.000000
# Champaign        1.000000  0.000000  0.000000  0.000000  4.000000  0.000000
# Chandler         0.272727  0.000000  0.090909  0.000000  4.181818  0.000000
# Charlotte        0.476190  0.000000  0.000000  0.000000  3.880952  0.000000
# Cottage Grove    0.000000  0.000000  0.000000  0.000000  4.000000  0.000000
# Edinburgh        0.273810  0.000000  0.000000  0.000000  3.952381  0.000000
# Ettlingen        0.000000  0.000000  0.000000  0.000000  5.000000  0.000000
# Fitchburg        1.000000  0.000000  0.000000  0.000000  4.000000  0.000000
# Gilbert          0.500000  0.000000  0.000000  0.000000  3.875000  0.000000
# Glendale         0.571429  0.000000  0.142857  0.000000  3.928571  0.142857
# Goodyear         0.666667  0.000000  0.000000  0.000000  4.166667  0.000000
# Harrisburg       1.000000  0.000000  0.000000  0.000000  4.500000  0.000000
# Henderson        0.750000  0.000000  0.000000  0.000000  3.875000  0.000000
# Indian Trail     1.000000  0.000000  0.000000  0.000000  4.500000  0.000000
# Karlsruhe        0.000000  0.000000  0.000000  0.000000  3.888889  0.000000
# Kitchener        0.166667  0.000000  0.000000  0.000000  4.000000  0.000000
# Lachine          1.000000  0.000000  0.000000  0.000000  3.000000  0.000000
# Las Vegas        0.426667  0.013333  0.013333  0.013333  3.726667  0.026667
# Laval            0.000000  0.000000  0.000000  0.000000  3.750000  0.000000
# Laveen           0.000000  0.000000  0.000000  0.000000  2.500000  0.000000
# Madison          0.468750  0.000000  0.000000  0.000000  3.968750  0.000000
# Maricopa         0.500000  0.000000  0.000000  0.000000  4.750000  0.000000
# Mesa             0.300000  0.000000  0.000000  0.000000  4.100000  0.000000
# Middleton        1.000000  0.000000  0.000000  0.000000  3.500000  0.000000
# Montréal         0.348837  0.000000  0.000000  0.011628  3.936047  0.000000
# North Las Vegas  1.000000  0.000000  0.000000  0.000000  4.000000  0.000000
# Peoria           0.000000  0.000000  0.000000  0.000000  5.000000  0.000000
# Phoenix          0.491525  0.000000  0.000000  0.000000  4.093220  0.000000
# Pineville        0.000000  0.000000  0.000000  0.000000  4.500000  0.000000
# Pittsburgh       0.258065  0.032258  0.000000  0.000000  3.887097  0.000000
# Queen Creek      0.000000  0.000000  0.000000  0.000000  4.250000  0.000000
# Saint-Leonard    0.000000  0.000000  0.000000  0.000000  4.500000  0.000000
# Scottsdale       0.464286  0.000000  0.000000  0.000000  4.125000  0.000000
# Sun City West    0.000000  0.000000  0.000000  0.000000  4.500000  0.000000
# Surprise         0.000000  0.000000  0.000000  0.000000  3.500000  0.000000
# Tega Cay         0.500000  0.000000  0.000000  0.000000  3.000000  0.000000
# Tempe            0.312500  0.062500  0.000000  0.000000  3.843750  0.000000
# Urbana           0.333333  0.000000  0.000000  0.000000  3.666667  0.000000
# Verdun           0.500000  0.000000  0.000000  0.000000  3.250000  0.000000
# Verona           0.000000  0.000000  0.000000  0.000000  4.000000  0.000000
# Waterloo         0.000000  0.000000  0.000000  0.000000  4.100000  0.000000
# Waunakee         1.000000  0.000000  0.000000  0.000000  4.500000  0.000000
# Wickenburg       1.000000  0.000000  0.000000  0.000000  4.500000  0.000000
# Youngtown        0.000000  0.000000  0.000000  0.000000  5.000000  0.000000
#
#                    trendy
# city
# Ahwatukee        0.000000
# Avondale         0.000000
# Bellevue         0.000000
# Brossard         0.000000
# Buckeye          0.250000
# Carefree         0.000000
# Carnegie         0.000000
# Casa Grande      0.000000
# Cave Creek       0.000000
# Champaign        0.000000
# Chandler         0.090909
# Charlotte        0.047619
# Cottage Grove    0.000000
# Edinburgh        0.000000
# Ettlingen        0.000000
# Fitchburg        0.000000
# Gilbert          0.125000
# Glendale         0.000000
# Goodyear         0.000000
# Harrisburg       0.000000
# Henderson        0.000000
# Indian Trail     0.000000
# Karlsruhe        0.000000
# Kitchener        0.000000
# Lachine          0.000000
# Las Vegas        0.093333
# Laval            0.000000
# Laveen           0.000000
# Madison          0.000000
# Maricopa         0.000000
# Mesa             0.000000
# Middleton        0.000000
# Montréal         0.023256
# North Las Vegas  0.000000
# Peoria           0.000000
# Phoenix          0.016949
# Pineville        0.000000
# Pittsburgh       0.032258
# Queen Creek      0.000000
# Saint-Leonard    0.000000
# Scottsdale       0.071429
# Sun City West    0.000000
# Surprise         0.000000
# Tega Cay         0.000000
# Tempe            0.000000
# Urbana           0.000000
# Verdun           0.000000
# Verona           0.000000
# Waterloo         0.000000
# Waunakee         0.000000
# Wickenburg       0.000000
# Youngtown        0.000000

# %%
coffee_with_ambience = coffee_full[~ pd.isnull(coffee_full['Ambience'])]
coffee_with_ambience
# Out:
#      Accepts Credit Cards Accepts Insurance Ages Allowed        Alcohol  \
# 1                    True               NaN          NaN           none
# 2                    True               NaN          NaN           none
# 12                   True               NaN          NaN           none
# 24                   True               NaN          NaN           none
# 31                  False               NaN          NaN           none
# 33                   True               NaN          NaN           none
# 42                   True               NaN          NaN           none
# 43                   True               NaN          NaN           none
# 52                   True               NaN          NaN           none
# 54                   True               NaN          NaN           none
# 76                   True               NaN          NaN       full_bar
# 78                   True               NaN          NaN           none
# 98                   True               NaN          NaN           none
# 103                  True               NaN          NaN           none
# 105                  True               NaN          NaN           none
# 112                  True               NaN          NaN       full_bar
# 115                  True               NaN          NaN           none
# 118                 False               NaN          NaN           none
# 119                  True               NaN          NaN           none
# 128                  True               NaN          NaN  beer_and_wine
# 129                  True               NaN          NaN  beer_and_wine
# 140                  True               NaN          NaN           none
# 141                  True               NaN          NaN           none
# 142                  True               NaN          NaN  beer_and_wine
# 143                  True               NaN          NaN  beer_and_wine
# 144                  True               NaN          NaN           none
# 150                  True               NaN          NaN  beer_and_wine
# 156                  True               NaN          NaN           none
# 158                  True               NaN          NaN           none
# 172                  True               NaN          NaN           none
# ...                   ...               ...          ...            ...
# 2111                 True               NaN          NaN           none
# 2115                 True               NaN          NaN           none
# 2125                 True               NaN          NaN           none
# 2128                 True               NaN          NaN           none
# 2133                  NaN               NaN          NaN       full_bar
# 2137                 True               NaN          NaN           none
# 2138                 True               NaN          NaN           none
# 2142                 True               NaN          NaN           none
# 2143                 True               NaN          NaN           none
# 2149                 True               NaN          NaN  beer_and_wine
# 2150                 True               NaN          NaN           none
# 2151                 True               NaN          NaN            NaN
# 2156                 True               NaN          NaN            NaN
# 2160                 True               NaN          NaN           none
# 2163                 True               NaN          NaN           none
# 2165                 True               NaN          NaN       full_bar
# 2174                 True               NaN          NaN           none
# 2181                 True               NaN          NaN           none
# 2205                 True               NaN          NaN            NaN
# 2208                False               NaN          NaN           none
# 2209                 True               NaN          NaN           none
# 2214                  NaN               NaN          NaN           none
# 2230                 True               NaN          NaN            NaN
# 2238                 True               NaN          NaN           none
# 2305                 True               NaN          NaN           none
# 2369                 True               NaN          NaN           none
# 2371                  NaN               NaN          NaN            NaN
# 2375                 True               NaN          NaN           none
# 2395                  NaN               NaN          NaN           none
# 2397                  NaN               NaN          NaN            NaN
#
#                                                Ambience  Attire   BYOB  \
# 1     {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 2     {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 12    {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 24    {'divey': True, 'romantic': False, 'hipster': ...  casual    NaN
# 31    {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 33    {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 42    {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 43    {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 52    {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 54    {'divey': True, 'romantic': False, 'hipster': ...  casual    NaN
# 76    {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 78    {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 98    {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 103   {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 105   {'divey': False, 'romantic': False, 'hipster':...  casual  False
# 112   {'divey': True, 'romantic': False, 'hipster': ...  casual    NaN
# 115   {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 118   {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 119   {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 128   {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 129   {'divey': True, 'romantic': False, 'hipster': ...  casual    NaN
# 140   {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 141   {'divey': False, 'romantic': False, 'hipster':...  casual  False
# 142   {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 143   {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 144   {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 150   {'divey': False, 'romantic': False, 'hipster':...  casual  False
# 156   {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 158   {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 172   {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# ...                                                 ...     ...    ...
# 2111  {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 2115  {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 2125  {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 2128  {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 2133  {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 2137  {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 2138  {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 2142  {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 2143  {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 2149  {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 2150  {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 2151  {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 2156  {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 2160  {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 2163  {'divey': True, 'romantic': False, 'hipster': ...  casual    NaN
# 2165  {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 2174  {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 2181  {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 2205  {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 2208  {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 2209  {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 2214  {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 2230  {'romantic': False, 'hipster': False, 'upscale...  casual    NaN
# 2238  {'divey': False, 'romantic': False, 'hipster':...     NaN    NaN
# 2305  {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 2369  {'divey': True, 'romantic': False, 'hipster': ...  casual    NaN
# 2371  {'divey': False, 'romantic': False, 'hipster':...     NaN    NaN
# 2375  {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
# 2395  {'divey': False, 'romantic': False, 'hipster':...     NaN    NaN
# 2397  {'divey': False, 'romantic': False, 'hipster':...  casual    NaN
#
#      BYOB/Corkage By Appointment Only Caters  ...   Smoking Take-out  \
# 1             NaN                 NaN  False  ...       NaN     True
# 2     yes_corkage                 NaN   True  ...       NaN     True
# 12            NaN                 NaN   True  ...       NaN     True
# 24            NaN                 NaN   True  ...       NaN     True
# 31            NaN                 NaN  False  ...       NaN     True
# 33            NaN                 NaN   True  ...       NaN     True
# 42            NaN                 NaN   True  ...       NaN     True
# 43            NaN                 NaN   True  ...       NaN     True
# 52            NaN                 NaN    NaN  ...       NaN     True
# 54            NaN                 NaN  False  ...       NaN     True
# 76            NaN               False  False  ...       NaN     True
# 78            NaN                 NaN   True  ...       NaN     True
# 98            NaN               False   True  ...       NaN     True
# 103           NaN                 NaN   True  ...       NaN     True
# 105      yes_free                 NaN  False  ...       NaN     True
# 112           NaN                 NaN  False  ...       NaN     True
# 115           NaN                 NaN   True  ...       NaN     True
# 118           NaN                 NaN    NaN  ...       NaN     True
# 119           NaN                 NaN  False  ...       NaN     True
# 128           NaN                 NaN  False  ...       NaN     True
# 129           NaN                 NaN   True  ...       NaN     True
# 140           NaN                 NaN  False  ...       NaN     True
# 141      yes_free                 NaN  False  ...       NaN     True
# 142           NaN                 NaN   True  ...       NaN     True
# 143           NaN                 NaN  False  ...       NaN     True
# 144           NaN                 NaN  False  ...       NaN     True
# 150      yes_free                 NaN   True  ...       NaN     True
# 156           NaN               False  False  ...       NaN     True
# 158           NaN                 NaN    NaN  ...       NaN     True
# 172           NaN                 NaN  False  ...       NaN     True
# ...           ...                 ...    ...  ...       ...      ...
# 2111          NaN                 NaN  False  ...       NaN     True
# 2115          NaN                 NaN  False  ...       NaN     True
# 2125          NaN                 NaN  False  ...       NaN     True
# 2128          NaN                 NaN    NaN  ...       NaN     True
# 2133          NaN                 NaN  False  ...       NaN     True
# 2137          NaN                 NaN    NaN  ...       NaN     True
# 2138          NaN                 NaN   True  ...       NaN     True
# 2142          NaN                 NaN  False  ...       NaN     True
# 2143          NaN                 NaN  False  ...       NaN     True
# 2149          NaN                 NaN  False  ...       NaN     True
# 2150          NaN                 NaN   True  ...       NaN     True
# 2151          NaN                 NaN    NaN  ...       NaN     True
# 2156          NaN                 NaN    NaN  ...       NaN     True
# 2160          NaN                 NaN  False  ...       NaN     True
# 2163          NaN                 NaN  False  ...       NaN     True
# 2165          NaN                 NaN   True  ...       NaN     True
# 2174          NaN                 NaN    NaN  ...       NaN     True
# 2181          NaN                 NaN    NaN  ...       NaN     True
# 2205          NaN                 NaN    NaN  ...       NaN     True
# 2208          NaN                 NaN  False  ...       NaN     True
# 2209          NaN               False  False  ...       NaN     True
# 2214          NaN                 NaN  False  ...       NaN     True
# 2230          NaN                 NaN    NaN  ...       NaN     True
# 2238          NaN                 NaN    NaN  ...   outdoor      NaN
# 2305          NaN                 NaN   True  ...       NaN     True
# 2369          NaN                 NaN   True  ...       NaN     True
# 2371          NaN                 NaN    NaN  ...       NaN     True
# 2375          NaN                 NaN   True  ...       NaN     True
# 2395          NaN                 NaN   True  ...       NaN     True
# 2397          NaN                 NaN    NaN  ...       NaN      NaN
#
#      Takes Reservations Waiter Service Wheelchair Accessible Wi-Fi  \
# 1                 False          False                  True  free
# 2                 False           True                  True  free
# 12                False          False                  True    no
# 24                False          False                 False    no
# 31                False          False                  True  free
# 33                False          False                 False  free
# 42                False          False                   NaN   NaN
# 43                False          False                  True    no
# 52                False          False                  True  free
# 54                False          False                  True  free
# 76                False           True                  True  free
# 78                False          False                  True  free
# 98                False           True                  True  free
# 103               False           True                  True  free
# 105               False           True                  True  free
# 112               False          False                  True  free
# 115               False            NaN                  True  free
# 118               False          False                  True  free
# 119               False          False                   NaN  free
# 128               False          False                  True  free
# 129               False          False                   NaN  free
# 140               False          False                  True  free
# 141               False          False                  True  free
# 142                True          False                  True  free
# 143               False          False                  True  free
# 144               False          False                  True  free
# 150               False          False                  True  free
# 156               False          False                  True  free
# 158                True          False                  True    no
# 172               False          False                  True  free
# ...                 ...            ...                   ...   ...
# 2111              False          False                  True  free
# 2115              False          False                   NaN  free
# 2125              False          False                  True  free
# 2128              False          False                   NaN   NaN
# 2133              False           True                   NaN  free
# 2137              False           True                  True    no
# 2138               True          False                  True  free
# 2142              False          False                   NaN  free
# 2143              False           True                   NaN  free
# 2149              False          False                  True  free
# 2150              False            NaN                   NaN  free
# 2151              False            NaN                   NaN  free
# 2156              False            NaN                   NaN   NaN
# 2160              False          False                  True  free
# 2163              False          False                  True  free
# 2165              False          False                  True  free
# 2174               True            NaN                   NaN   NaN
# 2181              False            NaN                  True  free
# 2205                NaN            NaN                  True  free
# 2208              False          False                   NaN  free
# 2209              False          False                 False  free
# 2214              False          False                   NaN  free
# 2230              False           True                   NaN   NaN
# 2238                NaN            NaN                  True  free
# 2305              False          False                   NaN  free
# 2369              False          False                  True    no
# 2371              False            NaN                   NaN  free
# 2375              False          False                  True  free
# 2395                NaN          False                   NaN   NaN
# 2397               True          False                   NaN   NaN
#
#                            _id             city  \
# 1     5848a79739a36819a9b30a55       Pittsburgh
# 2     5848a79739a36819a9b30a79       Pittsburgh
# 12    5848a79739a36819a9b30bc4       Pittsburgh
# 24    5848a79739a36819a9b30dd4        Charlotte
# 31    5848a79839a36819a9b3106d        Middleton
# 33    5848a79839a36819a9b31141          Madison
# 42    5848a79839a36819a9b31441          Phoenix
# 43    5848a79839a36819a9b31448          Phoenix
# 52    5848a79839a36819a9b3173b          Phoenix
# 54    5848a79839a36819a9b3176a          Phoenix
# 76    5848a79839a36819a9b321a6          Gilbert
# 78    5848a79839a36819a9b32301       Scottsdale
# 98    5848a79839a36819a9b32a8d       Wickenburg
# 103   5848a79939a36819a9b32dd7        Las Vegas
# 105   5848a79939a36819a9b32eae        Las Vegas
# 112   5848a79939a36819a9b334bc       Pittsburgh
# 115   5848a79939a36819a9b33566       Pittsburgh
# 118   5848a79939a36819a9b335d0       Pittsburgh
# 119   5848a79939a36819a9b335e2       Pittsburgh
# 128   5848a79939a36819a9b33808        Charlotte
# 129   5848a79939a36819a9b33861        Charlotte
# 140   5848a79939a36819a9b33bb8          Madison
# 141   5848a79939a36819a9b33bf6          Madison
# 142   5848a79939a36819a9b33c00          Madison
# 143   5848a79939a36819a9b33c0f          Madison
# 144   5848a79939a36819a9b33c14          Madison
# 150   5848a79939a36819a9b33d91        Fitchburg
# 156   5848a79939a36819a9b33e21           Urbana
# 158   5848a79939a36819a9b3435b         Chandler
# 172   5848a79939a36819a9b3493a            Tempe
# ...                        ...              ...
# 2111  5848a7a239a36819a9b45342       Scottsdale
# 2115  5848a7a239a36819a9b4536f          Madison
# 2125  5848a7a239a36819a9b45467             Mesa
# 2128  5848a7a239a36819a9b45494        Las Vegas
# 2133  5848a7a239a36819a9b45528          Phoenix
# 2137  5848a7a239a36819a9b4554f       Pittsburgh
# 2138  5848a7a239a36819a9b45553          Phoenix
# 2142  5848a7a239a36819a9b4559e          Gilbert
# 2143  5848a7a339a36819a9b455a8  North Las Vegas
# 2149  5848a7a339a36819a9b455fb          Phoenix
# 2150  5848a7a339a36819a9b4562a        Edinburgh
# 2151  5848a7a339a36819a9b45646          Madison
# 2156  5848a7a339a36819a9b456ff          Madison
# 2160  5848a7a339a36819a9b45733        Henderson
# 2163  5848a7a339a36819a9b4577e        Las Vegas
# 2165  5848a7a339a36819a9b457d5          Phoenix
# 2174  5848a7a339a36819a9b4588b        Las Vegas
# 2181  5848a7a339a36819a9b45903          Gilbert
# 2205  5848a79b39a36819a9b37088        Las Vegas
# 2208  5848a79b39a36819a9b3759f       Pittsburgh
# 2209  5848a79b39a36819a9b37768          Phoenix
# 2214  5848a79b39a36819a9b37f46         Montréal
# 2230  5848a79c39a36819a9b38eb3        Edinburgh
# 2238  5848a79c39a36819a9b399a2       Scottsdale
# 2305  5848a7a039a36819a9b40900       Pittsburgh
# 2369  5848a7a239a36819a9b4551c        Las Vegas
# 2371  5848a7a339a36819a9b458d2         Montréal
# 2375  5848a79b39a36819a9b374de       Scottsdale
# 2395  5848a7a239a36819a9b44c44        Henderson
# 2397  5848a7a339a36819a9b455c6         Montréal
#
#                                      name stars
# 1         Tazza D'oro Cafe & Espresso Bar   4.5
# 2     Quiet Storm Vegetarian & Vegan Cafe   4.0
# 12              Prestogeorge Coffee & Tea   4.5
# 24               Tic Toc Diner & Catering   4.5
# 31                  Prairie Cafe & Bakery   3.5
# 33                 Cool Beans Coffee Cafe   4.5
# 42      Cranberry Hills Eatery & Catering   4.0
# 43                      Bitter Creek Cafe   4.0
# 52                         Rainbow Donuts   4.0
# 54                Grinders Coffee Company   4.0
# 76                         Liberty Market   4.0
# 78                             Jolta Java   3.5
# 98           Chaparral Homemade Ice Cream   4.0
# 103                            Coffee Pub   4.5
# 105                           Tea Station   3.0
# 112                        Beehive Coffee   4.0
# 115                  Einstein Bros Bagels   3.5
# 118                              61C Cafe   3.5
# 119                             Starbucks   4.5
# 128                     Smelly Cat Coffee   4.5
# 129                         Laurel Market   4.5
# 140                          Steep & Brew   4.0
# 141                 Espresso Royale Caffe   3.5
# 142                Sunprint On The Square   3.5
# 143                             Barriques   4.0
# 144                           Ground Zero   4.0
# 150                      Barriques Market   4.0
# 156                        Caffe Paradiso   3.5
# 158                           Bosa Donuts   4.0
# 172                           Cupz Coffee   3.0
# ...                                   ...   ...
# 2111                          Boss Coffee   4.5
# 2115                       Sencha Tea Bar   4.0
# 2125                          Octane Cafe   5.0
# 2128      Delices Gourmands French Bakery   4.5
# 2133                   O to Go Coffee Bar   5.0
# 2137                        Geppetto Cafe   4.0
# 2138                           The Teapot   4.5
# 2142                            Starbucks   3.0
# 2143                TIABI Coffee & Waffle   4.5
# 2149          Oliver's Sophisticated Bean   5.0
# 2150                     Cairngorm Coffee   4.0
# 2151                Helbachs Coffee House   4.0
# 2156                Highland Espresso Bar   5.0
# 2160                            Starbucks   3.0
# 2163                            Tea Space   4.5
# 2165                Luci's at the Orchard   4.5
# 2174             Jolly Beans Cafe-Rainbow   4.0
# 2181                            Starbucks   4.0
# 2205                            Starbucks   4.0
# 2208                           Tango Cafe   4.5
# 2209                             Conspire   4.0
# 2214                 El-Mundo Cafe Bistro   3.0
# 2230                               Relish   4.5
# 2238                    Winfield's Coffee   4.0
# 2305              The Pop Stop Snack Shop   3.5
# 2369                            Donut Bar   4.5
# 2371                              Esquina   5.0
# 2375                 Einstein Bros Bagels   3.0
# 2395                        Scorpion Cafe   5.0
# 2397                            Le Coin B   4.0
#
# [554 rows x 39 columns]

# %%
coffee_amb_lm = ols('stars ~ C(wifi)', data=coffee_with_ambience).fit()
print(sm.stats.anova_lm(coffee_amb_lm, typ=2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/amniskin/anaconda3/lib/python3.5/site-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#     116     try:
# --> 117         return f(*args, **kwargs)
#     118     except Exception as e:
#
# /home/amniskin/anaconda3/lib/python3.5/site-packages/patsy/eval.py in eval(self, expr, source_name, inner_namespace)
#     165         return eval(code, {}, VarLookupDict([inner_namespace]
# --> 166                                             + self._namespaces))
#     167
#
# <string> in <module>()
#
# NameError: name 'wifi' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# <ipython-input-190-56083350abef> in <module>()
# ----> 1 coffee_amb_lm = ols('stars ~ C(wifi)', data=coffee_with_ambience).fit()
#       2 print(sm.stats.anova_lm(coffee_amb_lm, typ=2))
#
# /home/amniskin/anaconda3/lib/python3.5/site-packages/statsmodels/base/model.py in from_formula(cls, formula, data, subset, *args, **kwargs)
#     145         (endog, exog), missing_idx = handle_formula_data(data, None, formula,
#     146                                                          depth=eval_env,
# --> 147                                                          missing=missing)
#     148         kwargs.update({'missing_idx': missing_idx,
#     149                        'missing': missing})
#
# /home/amniskin/anaconda3/lib/python3.5/site-packages/statsmodels/formula/formulatools.py in handle_formula_data(Y, X, formula, depth, missing)
#      63         if data_util._is_using_pandas(Y, None):
#      64             result = dmatrices(formula, Y, depth, return_type='dataframe',
# ---> 65                                NA_action=na_action)
#      66         else:
#      67             result = dmatrices(formula, Y, depth, return_type='dataframe',
#
# /home/amniskin/anaconda3/lib/python3.5/site-packages/patsy/highlevel.py in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     308     eval_env = EvalEnvironment.capture(eval_env, reference=1)
#     309     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
# --> 310                                       NA_action, return_type)
#     311     if lhs.shape[1] == 0:
#     312         raise PatsyError("model is missing required outcome variables")
#
# /home/amniskin/anaconda3/lib/python3.5/site-packages/patsy/highlevel.py in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     163         return iter([data])
#     164     design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
# --> 165                                       NA_action)
#     166     if design_infos is not None:
#     167         return build_design_matrices(design_infos, data,
#
# /home/amniskin/anaconda3/lib/python3.5/site-packages/patsy/highlevel.py in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      68                                       data_iter_maker,
#      69                                       eval_env,
# ---> 70                                       NA_action)
#      71     else:
#      72         return None
#
# /home/amniskin/anaconda3/lib/python3.5/site-packages/patsy/build.py in design_matrix_builders(termlists, data_iter_maker, eval_env, NA_action)
#     694                                                    factor_states,
#     695                                                    data_iter_maker,
# --> 696                                                    NA_action)
#     697     # Now we need the factor infos, which encapsulate the knowledge of
#     698     # how to turn any given factor into a chunk of data:
#
# /home/amniskin/anaconda3/lib/python3.5/site-packages/patsy/build.py in _examine_factor_types(factors, factor_states, data_iter_maker, NA_action)
#     441     for data in data_iter_maker():
#     442         for factor in list(examine_needed):
# --> 443             value = factor.eval(factor_states[factor], data)
#     444             if factor in cat_sniffers or guess_categorical(value):
#     445                 if factor not in cat_sniffers:
#
# /home/amniskin/anaconda3/lib/python3.5/site-packages/patsy/eval.py in eval(self, memorize_state, data)
#     564         return self._eval(memorize_state["eval_code"],
#     565                           memorize_state,
# --> 566                           data)
#     567
#     568     __getstate__ = no_pickling
#
# /home/amniskin/anaconda3/lib/python3.5/site-packages/patsy/eval.py in _eval(self, code, memorize_state, data)
#     549                                  memorize_state["eval_env"].eval,
#     550                                  code,
# --> 551                                  inner_namespace=inner_namespace)
#     552
#     553     def memorize_chunk(self, state, which_pass, data):
#
# /home/amniskin/anaconda3/lib/python3.5/site-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#     122                                  origin)
#     123             # Use 'exec' to hide this syntax from the Python 2 parser:
# --> 124             exec("raise new_exc from e")
#     125         else:
#     126             # In python 2, we just let the original exception escape -- better
#
# /home/amniskin/anaconda3/lib/python3.5/site-packages/patsy/compat.py in <module>()
#
# PatsyError: Error evaluating factor: NameError: name 'wifi' is not defined
#     stars ~ C(wifi)
#             ^^^^^^^

# %%
tmp.iloc[0]
# Out:
# {'casual': True,
#  'classy': False,
#  'divey': False,
#  'hipster': False,
#  'intimate': False,
#  'romantic': False,
#  'touristy': False,
#  'trendy': False,
#  'upscale': False}

# %%
low_star_coffee = coffee_with_ambience[coffee_with_ambience['stars'] < 2.5]

# %% [markdown]
# ## [Bars] near [Wi-Fi]:
#
# ### Warning: This was a late addition, so it's not working very well. I've got it working in the mongo shell, but that doesn't do you much good.
# I'm out of time. Please check back later.

# %%
wifiLocs = getDF(business,
                 {'attributes.Wi-Fi': {'$exists': True, '$nin': ['no']}},
                 projection={'name': 1,
                             'attributes.Wi-Fi': 1,
                             'loc': 1},
                 preprocessor=getWifi
                )
# Out:
# Found 11148 records matching this predicate.

# %%
wifiLocs
# Out:
#                             _id  \
# 0      5848a79739a36819a9b309c6
# 1      5848a79739a36819a9b309d2
# 2      5848a79739a36819a9b309d5
# 3      5848a79739a36819a9b309e3
# 4      5848a79739a36819a9b309e4
# 5      5848a79739a36819a9b309ef
# 6      5848a79739a36819a9b309f1
# 7      5848a79739a36819a9b309f9
# 8      5848a79739a36819a9b309fe
# 9      5848a79739a36819a9b309ff
# 10     5848a79739a36819a9b30a06
# 11     5848a79739a36819a9b30a10
# 12     5848a79739a36819a9b30a1e
# 13     5848a79739a36819a9b30a2b
# 14     5848a79739a36819a9b30a4d
# 15     5848a79739a36819a9b30a55
# 16     5848a79739a36819a9b30a5c
# 17     5848a79739a36819a9b30a62
# 18     5848a79739a36819a9b30a63
# 19     5848a79739a36819a9b30a77
# 20     5848a79739a36819a9b30a79
# 21     5848a79739a36819a9b30a7d
# 22     5848a79739a36819a9b30aa5
# 23     5848a79739a36819a9b30aae
# 24     5848a79739a36819a9b30ab4
# 25     5848a79739a36819a9b30ae2
# 26     5848a79739a36819a9b30ae8
# 27     5848a79739a36819a9b30aec
# 28     5848a79739a36819a9b30af6
# 29     5848a79739a36819a9b30af7
# ...                         ...
# 11118  5848a79e39a36819a9b3d22a
# 11119  5848a79e39a36819a9b3d388
# 11120  5848a79e39a36819a9b3d777
# 11121  5848a79f39a36819a9b3e034
# 11122  5848a79f39a36819a9b3e189
# 11123  5848a79f39a36819a9b3ec8a
# 11124  5848a79f39a36819a9b3ed75
# 11125  5848a79f39a36819a9b3ee5b
# 11126  5848a79f39a36819a9b3fc82
# 11127  5848a79f39a36819a9b3fdc5
# 11128  5848a7a039a36819a9b40356
# 11129  5848a7a039a36819a9b409a5
# 11130  5848a7a039a36819a9b40f05
# 11131  5848a7a039a36819a9b4126f
# 11132  5848a7a039a36819a9b41654
# 11133  5848a7a139a36819a9b41c0f
# 11134  5848a7a139a36819a9b4266b
# 11135  5848a7a139a36819a9b42a44
# 11136  5848a7a139a36819a9b42aaa
# 11137  5848a7a139a36819a9b42c88
# 11138  5848a7a139a36819a9b42d2f
# 11139  5848a7a139a36819a9b43061
# 11140  5848a7a139a36819a9b43138
# 11141  5848a7a139a36819a9b437b0
# 11142  5848a7a239a36819a9b43ea0
# 11143  5848a7a239a36819a9b44016
# 11144  5848a7a239a36819a9b44ab0
# 11145  5848a7a239a36819a9b44b7d
# 11146  5848a7a239a36819a9b4510d
# 11147  5848a7a339a36819a9b4569c
#
#                                                      loc  \
# 0      {'coordinates': [-80.0675491, 40.4154859], 'ty...
# 1      {'coordinates': [-80.0849416, 40.3964688], 'ty...
# 2      {'coordinates': [-80.088557, 40.417419], 'type...
# 3      {'coordinates': [-79.9098858, 40.412012], 'typ...
# 4      {'coordinates': [-79.916958, 40.407091], 'type...
# 5      {'coordinates': [-79.9141865, 40.4092932], 'ty...
# 6      {'coordinates': [-79.9017997, 40.4097098], 'ty...
# 7      {'coordinates': [-79.9173143507142, 40.4070737...
# 8      {'coordinates': [-79.9155451418884, 40.4108743...
# 9      {'coordinates': [-79.9141364, 40.410967], 'typ...
# 10     {'coordinates': [-79.916603, 40.407174], 'type...
# 11     {'coordinates': [-79.9180766055519, 40.4089628...
# 12     {'coordinates': [-80.074153, 40.472505], 'type...
# 13     {'coordinates': [-80.06235, 40.492067], 'type'...
# 14     {'coordinates': [-79.9223818, 40.4588237], 'ty...
# 15     {'coordinates': [-79.9188657, 40.4748883], 'ty...
# 16     {'coordinates': [-79.9184470785759, 40.4588455...
# 17     {'coordinates': [-79.9265025, 40.4609626], 'ty...
# 18     {'coordinates': [-79.9253403, 40.4605052], 'ty...
# 19     {'coordinates': [-79.924797, 40.458138], 'type...
# 20     {'coordinates': [-79.935388, 40.464485], 'type...
# 21     {'coordinates': [-79.8954753, 40.4481991], 'ty...
# 22     {'coordinates': [-79.9981599, 40.4523049], 'ty...
# 23     {'coordinates': [-79.994957, 40.455167], 'type...
# 24     {'coordinates': [-80.0015054, 40.4566092], 'ty...
# 25     {'coordinates': [-80.0493988, 40.3885913], 'ty...
# 26     {'coordinates': [-80.0302799, 40.4193308], 'ty...
# 27     {'coordinates': [-80.0492732, 40.3886283], 'ty...
# 28     {'coordinates': [-80.0409102, 40.3897336], 'ty...
# 29     {'coordinates': [-80.036197, 40.397846], 'type...
# ...                                                  ...
# 11118  {'coordinates': [-115.1176266, 36.0220804], 't...
# 11119  {'coordinates': [-115.1370794, 36.1087848], 't...
# 11120  {'coordinates': [-115.2622382, 36.1434735], 't...
# 11121  {'coordinates': [-80.8398637, 35.1320288], 'ty...
# 11122  {'coordinates': [-111.909691, 33.348038], 'typ...
# 11123  {'coordinates': [-111.999092102051, 33.4348794...
# 11124  {'coordinates': [-115.036590576172, 36.0661010...
# 11125  {'coordinates': [-80.9385, 35.1361], 'type': '...
# 11126  {'coordinates': [-115.141310691833, 36.1107324...
# 11127  {'coordinates': [-111.9307011, 33.4937481], 't...
# 11128  {'coordinates': [-115.175495425484, 36.1168506...
# 11129  {'coordinates': [-111.973490626984, 33.2876093...
# 11130  {'coordinates': [-73.6002691, 45.5348293], 'ty...
# 11131  {'coordinates': [-111.721543, 33.6051307], 'ty...
# 11132  {'coordinates': [-111.979302954077, 33.5811612...
# 11133  {'coordinates': [-3.20149060488528, 55.9428446...
# 11134  {'coordinates': [-115.2257416, 36.1075559], 't...
# 11135  {'coordinates': [-115.119583514124, 36.0129202...
# 11136  {'coordinates': [-111.8555748, 33.6269887], 't...
# 11137  {'coordinates': [-115.1350531, 36.1248998], 't...
# 11138  {'coordinates': [-79.9081962, 40.4852665], 'ty...
# 11139  {'coordinates': [-115.168028, 36.1276112], 'ty...
# 11140  {'coordinates': [-89.359735, 43.0944829], 'typ...
# 11141  {'coordinates': [-115.3334588, 36.1483238], 't...
# 11142  {'coordinates': [-73.592862, 45.451144], 'type...
# 11143  {'coordinates': [-112.078715, 33.5096672], 'ty...
# 11144  {'coordinates': [-88.2272529602051, 40.1092429...
# 11145  {'coordinates': [-115.260817, 36.176313], 'typ...
# 11146  {'coordinates': [-115.136013329029, 36.1049214...
# 11147  {'coordinates': [-115.291302837431, 36.1691111...
#
#                                                  name  wifi
# 0                               Alexion's Bar & Grill  free
# 1                                      Rocky's Lounge  free
# 2       Extended Stay America - Pittsburgh - Carnegie  free
# 3                                          McDonald's  free
# 4                                           Starbucks  free
# 5                                     Dave & Buster's  free
# 6                                             Wendy's  free
# 7                                           Bar Louie  free
# 8                                         TGI Fridays  free
# 9                                Uno Pizzeria & Grill  free
# 10                                       Panera Bread  free
# 11                             Mitchell's Fish Market  free
# 12                                    Broadway Brunch  free
# 13                                         McDonald's  free
# 14                    Minutello's Restaurant & Lounge  free
# 15                    Tazza D'oro Cafe & Espresso Bar  free
# 16                                         McDonald's  free
# 17      Carnegie Library of Pittsburgh - East Liberty  free
# 18                                      Shadow Lounge  free
# 19                                             Casbah  free
# 20                Quiet Storm Vegetarian & Vegan Cafe  free
# 21                                East End Food Co-Op  free
# 22                                   The Priory Hotel  free
# 23                                Teutonia Mannerchor  free
# 24                         Legends of The North Shore  free
# 25                                        Sushi Three  free
# 26                                Days Inn Pittsburgh  free
# 27                              Suburban Dry Cleaners  free
# 28                                      Cain's Saloon  free
# 29                                 The Laundry Basket  free
# ...                                               ...   ...
# 11118                        Coco's Family Restaurant  free
# 11119                               Cedars Restaurant  free
# 11120                            The Las Vegas Grille  free
# 11121                                    Flavors Cafe  free
# 11122                                 Pizza 'N Greens  free
# 11123                              Sauce Pizza & Wine  free
# 11124                                       Starbucks  free
# 11125                                             KFC  free
# 11126                            Einstein Bros Bagels  free
# 11127                              Kaleidoscope Juice  free
# 11128                    Nobu Hotel at Caesars Palace  free
# 11129                         Phoenix Premium Outlets  free
# 11130                              L'Armoire à Glaces  free
# 11131                   Fountain Hills Branch Library  free
# 11132                                       Starbucks  free
# 11133                                Machina Espresso  free
# 11134                                  Mob City Pizza  free
# 11135                                  Eis Cream Cafe  free
# 11136                                 Cream City Cafe  free
# 11137                                  Pineapple Park  free
# 11138                                      Choderwood  free
# 11139                                 Sticks & Shakes  free
# 11140                              SuperCharge! Foods  free
# 11141                       The Art of Vision by Amel  free
# 11142                                    Cafe Central  free
# 11143                            First Draft Book Bar  free
# 11144                                       Starbucks  free
# 11145  Cobrinha Brazilian Jiu Jitsu Academy Las Vegas  free
# 11146                              Chewy Boba Company  free
# 11147                                        Du-par's  free
#
# [11148 rows x 4 columns]

# %%
tmp = business.find_one({'categories': {'$in': ['Bars']}},
                        {'loc': 1}
                       )

# %%
tmp['loc']
# Out:
# {'coordinates': [-79.8662107, 40.4088301], 'type': 'Point'}

# %%
tmpBus = business.find({
        'loc': SON([('$near',
                     {'$geometry': SON([('type', 'Point'),
                                        ('coordinates', tmp['loc']['coordinates'])
                                       ])}),
                    ('$maxDistance', 1)
                   ])
    })

# %%
tmpBus1 = list(tmpBus)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-243-22c35aa2b848> in <module>()
# ----> 1 tmpBus1 = list(tmpBus)
#
# /home/amniskin/anaconda3/lib/python3.5/site-packages/pymongo/cursor.py in next(self)
#    1088             raise StopIteration
#    1089         _db = self.__collection.database
# -> 1090         if len(self.__data) or self._refresh():
#    1091             if self.__manipulate:
#    1092                 return _db._fix_outgoing(self.__data.popleft(),
#
# /home/amniskin/anaconda3/lib/python3.5/site-packages/pymongo/cursor.py in _refresh(self)
#    1010                                        self.__limit,
#    1011                                        self.__batch_size,
# -> 1012                                        self.__read_concern))
#    1013             if not self.__id:
#    1014                 self.__killed = True
#
# /home/amniskin/anaconda3/lib/python3.5/site-packages/pymongo/cursor.py in __send_message(self, operation)
#     901             doc = helpers._unpack_response(response=data,
#     902                                            cursor_id=self.__id,
# --> 903                                            codec_options=self.__codec_options)
#     904             if from_command:
#     905                 helpers._check_command_response(doc['data'][0])
#
# /home/amniskin/anaconda3/lib/python3.5/site-packages/pymongo/helpers.py in _unpack_response(response, cursor_id, codec_options)
#     135                                error_object.get("$err"),
#     136                                error_object.get("code"),
# --> 137                                error_object)
#     138
#     139     result = {"cursor_id": struct.unpack("<q", response[4:12])[0],
#
# OperationFailure: database error: Can't canonicalize query: BadValue geo near accepts just one argument when querying for a GeoJSON point. Extra field found: $maxDistance: 1

# %%
db.command({'geoNear': 'academic_business',
            'near': tmp['loc']['coordinates'],
            'spherical': True
           })
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-236-1bd8cd8abe70> in <module>()
#       1 db.command({'geoNear': 'academic_business',
#       2             'near': tmp['loc']['coordinates'],
# ----> 3             'spherical': True
#       4            })
#
# /home/amniskin/anaconda3/lib/python3.5/site-packages/pymongo/database.py in command(self, command, value, check, allowable_errors, read_preference, codec_options, **kwargs)
#     479             return self._command(sock_info, command, slave_ok, value,
#     480                                  check, allowable_errors, read_preference,
# --> 481                                  codec_options, **kwargs)
#     482
#     483     def _list_collections(self, sock_info, slave_okay, criteria=None):
#
# /home/amniskin/anaconda3/lib/python3.5/site-packages/pymongo/database.py in _command(self, sock_info, command, slave_ok, value, check, allowable_errors, read_preference, codec_options, **kwargs)
#     391                                  codec_options,
#     392                                  check,
# --> 393                                  allowable_errors)
#     394
#     395     def command(self, command, value=1, check=True,
#
# /home/amniskin/anaconda3/lib/python3.5/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern)
#     237                            check, allowable_errors, self.address,
#     238                            check_keys, self.listeners, self.max_bson_size,
# --> 239                            read_concern)
#     240         except OperationFailure:
#     241             raise
#
# /home/amniskin/anaconda3/lib/python3.5/site-packages/pymongo/network.py in command(sock, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern)
#     100         response_doc = unpacked['data'][0]
#     101         if check:
# --> 102             helpers._check_command_response(response_doc, None, allowable_errors)
#     103     except Exception as exc:
#     104         if publish:
#
# /home/amniskin/anaconda3/lib/python3.5/site-packages/pymongo/helpers.py in _check_command_response(response, msg, allowable_errors)
#     203
#     204             msg = msg or "%s"
# --> 205             raise OperationFailure(msg % errmsg, code, response)
#     206
#     207
#
# OperationFailure: no such cmd: near

# %%
barsNearWifi = getDF(business,
                     {'categories': {'$in': ['Coffee & Tea']}},
                     projection={'attributes': 1,
                                 'city': 1,
                                 'stars': 1},
                     preprocessor=getAllAttrs
                    )
# Out:
# Found 2399 records matching this predicate.
